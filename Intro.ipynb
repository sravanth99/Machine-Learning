# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
plt.plot(10,10)
# Out:
# <img src="data:image/png;base64,..." width="488.80105186884117">

# %%
plt.plot(10,10,'.','green')
plt.show()

# %%
#Without scripting layer
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure
fig = Figure()
canvas = FigureCanvasAgg(fig)
ax = fig.add_subplot(111)
ax.plot(3,2,'o')
canvas.print_png('test.png')

# %%
# %%html
# <img src = 'test.png'/>
# Out:
# <img src = 'test.png'/>

# %%
plt.figure()#New figure
plt.plot(2,1,'o')
ax = plt.gca() #gca : get the current axes
ax.axis([0,5,0,10]) #Set the x and y limits
# Out:
# <img src="data:image/png;base64,..." width="431.4887991564569">
# [0, 5, 0, 10]

# %%
plt.figure()
plt.plot(1,1,'o')
plt.plot(2,2,'o')
plt.plot(4,4,'o')
# Axes recognizes these points as diiferent series so color is different.
# Out:
# <img src="data:image/png;base64,..." width="431.4887991564569">

# %%
ax = plt.gca()
ax.get_children()
# Out:
# [<matplotlib.lines.Line2D at 0x2273d84d908>,
#  <matplotlib.lines.Line2D at 0x2273d0eb9e8>,
#  <matplotlib.lines.Line2D at 0x2273d84dcf8>,
#  <matplotlib.spines.Spine at 0x2273d5693c8>,
#  <matplotlib.spines.Spine at 0x2273d5697f0>,
#  <matplotlib.spines.Spine at 0x2273ce730f0>,
#  <matplotlib.spines.Spine at 0x2273ce73668>,
#  <matplotlib.axis.XAxis at 0x2273d569908>,
#  <matplotlib.axis.YAxis at 0x2273ce5c4a8>,
#  Text(0.5, 1, ''),
#  Text(0.0, 1, ''),
#  Text(1.0, 1, ''),
#  <matplotlib.patches.Rectangle at 0x2273d82d400>]
