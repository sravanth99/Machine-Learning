# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Box and Whisker Plots :

# %%
import pandas as pd
normal = np.random.normal(loc=0.0,scale = 1.0,size=10000)
gamma = np.random.gamma(2,size=10000)
random = np.random.random(size=10000)
df = pd.DataFrame({'normal':normal,'gamma':gamma,'random':random})

# %%
df.head()
# Out:
#      normal     gamma    random
# 0  1.418480  0.893750  0.894088
# 1 -0.419486  2.321750  0.466461
# 2 -0.752252  2.117933  0.477360
# 3  0.946318  0.586798  0.436627
# 4 -0.068126  1.560036  0.574699

# %%
df.describe()
# Out:
#              normal         gamma        random
# count  10000.000000  10000.000000  10000.000000
# mean       0.013997      1.992488      0.505268
# std        0.999628      1.439469      0.287340
# min       -3.888323      0.002526      0.000053
# 25%       -0.666389      0.936920      0.258884
# 50%        0.013468      1.669087      0.512574
# 75%        0.683843      2.681849      0.755762
# max        4.160945     13.420639      0.999996

# %%
# Mean or median of the data is plotted as a straight line
plt.figure()
box = plt.boxplot(df['normal'],whis='range')
# Out:
# <img src="data:image/png;base64,..." width="639.6574411922437">

# %%
plt.clf()# cLear the current figure
plt.boxplot([df['random'],df['normal'],df['gamma']],whis='range') # we have to pass the list of columns to it
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16b89e18630>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16b8c5ceeb8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16b8c5ce4a8>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x16b8c5dd588>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x16b8c5dd8d0>,
# ...
#  'means': []}

# %%
plt.figure()
# we detect the outliers by putting whis parameter off
plt.boxplot([df['random'],df['normal'],df['gamma']])
# Out:
# <img src="data:image/png;base64,..." width="639.6574411922437">
# {'whiskers': [<matplotlib.lines.Line2D at 0x16b8e0fe898>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16b8e0fef28>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16b8e0fe518>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x16b8e1055f8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x16b8e105940>,
# ...
#  'means': []}
